# %%
import os
import sys
import re
from tqdm import tqdm
import argparse
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# from Bio import SeqIO
from datetime import datetime
from numpy.random import randint
import torch
import torch.utils.data
from torch.utils.data import random_split
import torch.nn as nn
import torch.nn.functional as F
from torch.utils.data.dataloader import DataLoader

import matplotlib
import matplotlib.pyplot as plt

# %%
# Add Cuda availability

print(f'torch vesrion:{torch.__version__}  cuda availability:{torch.cuda.is_available()} with {torch.cuda.device_count()} GPU devices')

def get_default_device():
    """Pick GPU if available, else CPU"""
    if torch.cuda.is_available():
        return torch.device('cuda')
    else:
        return torch.device('cpu')
    
def to_device(data, device):
    """Move tensor(s) to chosen device"""
    if isinstance(data, (list,tuple)):
        return [to_device(x, device) for x in data]
    return data.to(device, non_blocking=True)

class DeviceDataLoader(DataLoader):
    """Wrap a dataloader to move data to a device"""
    def __init__(self, dl, device, batchSize, *args, **kwargs):
        super(DeviceDataLoader, self).__init__(dl, batchSize, *args, **kwargs)
        self.dl = dl
        self.device = device
        # for b in self.dl: 
        #   yield to_device(b, self.device)
        
    def __iter__(self):
        """Yield a batch of data after moving it to device"""
        # super(DeviceDataLoader, self).__iter__()
        for b in self.dl: 
            yield to_device(b, self.device)

    def __len__(self):
        """Number of batches"""
        return len(self.dl)

device = get_default_device()
print(f'{device} set as the default device')
# Out:
# torch vesrion:1.9.0+cu102  cuda availability:False with 0 GPU devices
# cpu set as the default device

# %%
k = 7

# %%
from HDF5datasetLogisticPandas import HDF5Dataset
from WeightsCreator import make_weights_for_balanced_classes
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-4-cea4ed695d4b> in <module>
# ----> 1 from HDF5datasetLogisticPandas import HDF5Dataset
#       2 from WeightsCreator import make_weights_for_balanced_classes
#
# ModuleNotFoundError: No module named 'HDF5datasetLogisticPandas'

# %%
inputFeatures = int((4**k) / 2) + 15
# inputFeatures = 2
layer_array = [512, 512, 256, 256]
outputSize = 2
momentum = 0.4
dropoutProb = 0.5
batchSize = 200
num_epochs = 5
opt_func = torch.optim.Adam
lr = 0.001
num_workers = 2

# %%
print('Importing the dataset....')
# trainingDataset = HDF5Dataset('/home/chamikanandasiri/Datasets/DNAML_Plasmid/DNAML_plasmid_train.h5', True)
# trainingDataset = HDF5Dataset(
#     '/home/chamikanandasiri/Test/Plasmid_0.1_Dataset.h5', True)
trainingDataset = HDF5Dataset(
    '/home/chamikanandasiri/Datasets/plasbin_100K', True, data_cache_size=100, label_threshold=13)
datasetsize = len(trainingDataset)

train_size = int(0.8 * len(trainingDataset))
val_size = len(trainingDataset) - train_size

print('\nSplitting Training/Validation datasets....')
train_ds, val_ds = random_split(trainingDataset, [train_size, val_size])
print('==== Dataset processed ====')
# Out:
# Importing the dataset....
#
# Splitting Training/Validation datasets....
# ==== Dataset processed ====

# %%
# ind = torch.tensor(train_ds.indices)
# tens = train_ds.dataset.get_label_values(ind)

# %%
# weights = make_weights_for_balanced_classes(outputSize, tens)
# sampler = torch.utils.data.sampler.WeightedRandomSampler(weights, train_size)

# train_dl = DataLoader(train_ds, batchSize, shuffle=False, num_workers=num_workers, pin_memory=True, sampler=sampler)
# val_dl = DataLoader(val_ds, batchSize, num_workers=num_workers, pin_memory=True)

#=================================================================================================
train_dl = DataLoader(train_ds, batchSize, shuffle=True, num_workers=num_workers, pin_memory=True)
val_dl = DataLoader(val_ds, batchSize, num_workers=num_workers, pin_memory=True)

# %%
@torch.no_grad()
def evaluate(model, val_loader):
    model.eval()
    outputs = [model.validation_step(batch) for batch in val_loader]
    return model.validation_epoch_end(outputs)

def accuracy(outputs, labels):
    _, preds = torch.max(outputs, dim=1)
    return torch.tensor(torch.sum(preds == labels).item() / len(preds))

def plot_accuracies(history):
    accuracies = [x['val_acc'] for x in history]
    plt.plot(accuracies, '-x')
    plt.xlabel('epoch')
    plt.ylabel('accuracy')
    plt.title('Accuracy vs. No. of epochs');

def plot_losses(history):
    train_losses = [x.get('train_loss') for x in history]
    val_losses = [x['val_loss'] for x in history]
    plt.plot(train_losses, '-bx')
    plt.plot(val_losses, '-rx')
    plt.xlabel('epoch')
    plt.ylabel('loss')
    plt.legend(['Training', 'Validation'])
    plt.title('Loss vs. No. of epochs');

def fit(epochs, lr, model, train_loader, val_loader, opt_func=torch.optim.SGD):
    history = []
    optimizer = opt_func(model.parameters(), lr)
    for epoch in range(epochs):
        # Training Phase 
        model.train()
        train_losses = []
        for batch in tqdm(train_loader):
            loss = model.training_step(batch)
            train_losses.append(loss)
            loss.backward()
            optimizer.step()
            optimizer.zero_grad()
        # Validation phase
        result = evaluate(model, val_loader)
        result['train_loss'] = torch.stack(train_losses).mean().item()
        model.epoch_end(epoch, result)
        history.append(result)
    return history

class Model(nn.Module):
    def __init__(self, in_size, layer_array = [512, 512, 256, 256], out_size = 28):
        super().__init__()
        self.network = nn.Sequential(
          nn.Linear(in_size, layer_array[0]),
          nn.ReLU(),
          # nn.Dropout(dropoutProb),
          nn.Linear(layer_array[0], layer_array[1]),
          nn.ReLU(),
          # nn.Dropout(dropoutProb),
          nn.Linear(layer_array[1], layer_array[2]),
          nn.ReLU(),
          # nn.Dropout(dropoutProb),
          nn.Linear(layer_array[2], layer_array[3]),
          nn.ReLU(),
          # nn.Dropout(dropoutProb),
          nn.Linear(layer_array[3], out_size)
        )
        
    def forward(self, xb):
        softmax = nn.LogSoftmax(dim=0)
        return softmax(self.network(xb))

    def training_step(self, batch):
        values, labels, f_id = batch 
        values = values.to(device)
        labels = labels.to(device)
        out = self(values)                  # Generate predictions
        loss = nn.functional.nll_loss(out, labels) # Calculate loss
        return loss
    
    def validation_step(self, batch):
        values, labels, f_id = batch 
        values = values.to(device)
        labels = labels.to(device)
        out = self(values)                    # Generate predictions
        loss = nn.functional.nll_loss(out, labels)   # Calculate loss
        acc = accuracy(out, labels)           # Calculate accuracy
        return {'val_loss': loss, 'val_acc': acc}
        
    def validation_epoch_end(self, outputs):
        batch_losses = [x['val_loss'] for x in outputs]
        epoch_loss = torch.stack(batch_losses).mean()   # Combine losses
        batch_accs = [x['val_acc'] for x in outputs]
        epoch_acc = torch.stack(batch_accs).mean()      # Combine accuracies
        return {'val_loss': epoch_loss.item(), 'val_acc': epoch_acc.item()}
    
    def epoch_end(self, epoch, result):
        print("Epoch [{}], val_loss: {:.4f}, val_acc: {:.4f}".format(epoch, result['val_loss'], result['val_acc']))

# def predict(value, model):
#   xb = value
#   # //:TODO Check torch.stack
#   # xb = torch.stack(value)
#   yb = model(xb)
#   _, preds  = torch.max(yb, dim=0)
#   return preds

def predict(value, model):
    # Convert to a batch of 1
    xb = to_device(value, device)
    # Get predictions from model
    yb = model(xb)
    # print(yb)
    # Pick index with highest probability   
    _, preds  = torch.max(yb, dim=0)
    # print(torch.max(yb, dim=0)[1])
    # Retrieve the class label
    return preds.item()

# %%
model = Model(inputFeatures, layer_array, outputSize)
model = to_device(model, device)
model
# Out:
# Model(
#   (network): Sequential(
#     (0): Linear(in_features=8207, out_features=512, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=512, out_features=512, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=512, out_features=256, bias=True)
#     (5): ReLU()
#     (6): Linear(in_features=256, out_features=256, bias=True)
#     (7): ReLU()
#     (8): Linear(in_features=256, out_features=2, bias=True)
#   )
# )

# %%
model.double()
history = fit(num_epochs, lr, model, train_dl, val_dl, opt_func)
# Out:
#   8%|▊         | 25/321 [03:17<39:00,  7.91s/it]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-11-f1ee0395159e> in <module>
#       1 model.double()
# ----> 2 history = fit(num_epochs, lr, model, train_dl, val_dl, opt_func)
#
# <ipython-input-9-1c4c40aa1b52> in fit(epochs, lr, model, train_loader, val_loader, opt_func)
#      36             loss = model.training_step(batch)
#      37             train_losses.append(loss)
# ---> 38             loss.backward()
#      39             optimizer.step()
#      40             optimizer.zero_grad()
#
# ~/.local/lib/python3.6/site-packages/torch/_tensor.py in backward(self, gradient, retain_graph, create_graph, inputs)
#     253                 create_graph=create_graph,
#     254                 inputs=inputs)
# --> 255         torch.autograd.backward(self, gradient, retain_graph, create_graph, inputs=inputs)
#     256
#     257     def register_hook(self, hook):
#
# ~/.local/lib/python3.6/site-packages/torch/autograd/__init__.py in backward(tensors, grad_tensors, retain_graph, create_graph, grad_variables, inputs)
#     147     Variable._execution_engine.run_backward(
#     148         tensors, grad_tensors_, retain_graph, create_graph, inputs,
# --> 149         allow_unreachable=True, accumulate_grad=True)  # allow_unreachable flag
#     150
#     151
#
# KeyboardInterrupt:

# %% [markdown]
# 0:01:40.396880\
# 0:02:31.303028

# %%
plot_accuracies(history)

# %%
plot_losses(history)

# %%
testingDataset = HDF5Dataset(
    '/home/chamikanandasiri/Test/Plasmid(testing0.008)Dataset.h5', True)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-14-394d0c38ee84> in <module>
#       1 testingDataset = HDF5Dataset(
# ----> 2     '/home/chamikanandasiri/Test/Plasmid(testing0.008)Dataset.h5', True)
#
# ~/plasbin/Scripts/PlasChromoDetectionModel/HDF5datasetLogisticPandas.py in __init__(self, file_path, isTraining, data_cache_size, plas_chro_labeling, label_threshold)
#      15         if (isTraining):
#      16             self.data_info = pd.read_csv(
# ---> 17                 file_path+'/h5_data_infos/training_data_info.csv')
#      18             self.label_info = pd.read_csv(
#      19                 file_path + '/h5_data_infos/training_label_info.csv')
#
# ~/.local/lib/python3.6/site-packages/pandas/io/parsers.py in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, dialect, error_bad_lines, warn_bad_lines, delim_whitespace, low_memory, memory_map, float_precision)
#     686     )
#     687
# --> 688     return _read(filepath_or_buffer, kwds)
#     689
#     690
#
# ~/.local/lib/python3.6/site-packages/pandas/io/parsers.py in _read(filepath_or_buffer, kwds)
#     452
#     453     # Create the parser.
# --> 454     parser = TextFileReader(fp_or_buf, **kwds)
#     455
#     456     if chunksize or iterator:
#
# ~/.local/lib/python3.6/site-packages/pandas/io/parsers.py in __init__(self, f, engine, **kwds)
#     946             self.options["has_index_names"] = kwds["has_index_names"]
#     947
# --> 948         self._make_engine(self.engine)
#     949
#     950     def close(self):
#
# ~/.local/lib/python3.6/site-packages/pandas/io/parsers.py in _make_engine(self, engine)
#    1178     def _make_engine(self, engine="c"):
#    1179         if engine == "c":
# -> 1180             self._engine = CParserWrapper(self.f, **self.options)
#    1181         else:
#    1182             if engine == "python":
#
# ~/.local/lib/python3.6/site-packages/pandas/io/parsers.py in __init__(self, src, **kwds)
#    2008         kwds["usecols"] = self.usecols
#    2009
# -> 2010         self._reader = parsers.TextReader(src, **kwds)
#    2011         self.unnamed_cols = self._reader.unnamed_cols
#    2012
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader.__cinit__()
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader._setup_parser_source()
#
# FileNotFoundError: [Errno 2] No such file or directory: '/home/chamikanandasiri/Test/Plasmid(testing0.008)Dataset.h5/h5_data_infos/training_data_info.csv'

# %%
test_dl = DataLoader(testingDataset, batchSize, num_workers=4, pin_memory=True)

# %%
cor = []
incor = []
for i in range(580):
    prediction = predict(testingDataset[i][0], model)
    label = testingDataset[i][1].item()
    # print(label)
    if(prediction == label):
        cor.append([label, prediction])
    else:
        incor.append([label, prediction])

# %%
correct_df = pd.DataFrame(cor, columns=['label', 'prediction'])
incorrect_df = pd.DataFrame(incor, columns=['label', 'prediction'])

# %%
incorrect_df.head()
# Out:
#    label  prediction
# 0      1           7
# 1      0           9
# 2      0           9
# 3      0           9
# 4      0           9

# %%
incorrect_df['prediction'].value_counts()
# Out:
# 9    208
# 2    204
# 7     99
# 1     29
# Name: prediction, dtype: int64

# %%
correct_df.head()
# Out:
#    label  prediction
# 0      2           2
# 1      2           2
# 2      2           2
# 3      2           2
# 4      2           2

# %%
correct_df['prediction'].value_counts()
# Out:
# 2    34
# 7     4
# 1     2
# Name: prediction, dtype: int64

# %%
training_df = pd.DataFrame(tens,columns=['label'])

# %%
training_df.label.value_counts()
# Out:
# 0    1425
# 1     238
# 2      93
# 6      29
# 7      17
# 5      15
# 8      11
# 9       7
# 3       3
# 4       2
# Name: label, dtype: int64

# %%
cat.label.value_counts()
# Out:
# 0    28652
# 1     4785
# 2     1871
# 6      582
# 7      343
# 5      303
# 8      221
# 9      142
# 3       61
# 4       40
# Name: label, dtype: int64

# %%
from HDF5dataset import HDF5Dataset
cacheDataset = HDF5Dataset('/home/chamikanandasiri/plasbin/h5_files/training.h5', False, data_cache_size=3,label_threshold=6)
loadedDataset = HDF5Dataset('/home/chamikanandasiri/plasbin/h5_files/training.h5', True, data_cache_size=3,label_threshold=6)
# Out:
# 100%|██████████| 6399/6399 [00:03<00:00, 1652.45it/s]
# 100%|██████████| 6399/6399 [00:06<00:00, 998.44it/s]

# %%
cacheDataset[73]
# Out:
# (tensor([0., 0., 0.,  ..., 0., 0., 0.], dtype=torch.float64), tensor(1))

# %%
loadedDataset[5]
# Out:
# (tensor([0., 0., 0.,  ..., 0., 0., 0.], dtype=torch.float64), tensor(0))

# %%
cacheDataset.data_cache
# Out:
# {'1001_c': [array([0., 0., 0., ..., 0., 0., 0.]), array([7])],
#  '1024_c': [array([0., 0., 0., ..., 0., 0., 0.]), array([8])],
#  '1043_c': [array([0., 0., 0., ..., 0., 0., 0.]), array([8])]}

# %%
loadedDataset.data_cache
# Out:
# {'0_c': [array([0., 0., 0., ..., 0., 0., 0.]), array([7])],
#  '0_p': [array([0., 0., 0., ..., 0., 0., 0.]), array([0])],
#  '1000_c': [array([0., 0., 0., ..., 0., 0., 0.]), array([7])],
#  '1001_c': [array([0., 0., 0., ..., 0., 0., 0.]), array([7])],
#  '1001_p': [array([0., 0., 0., ..., 0., 0., 0.]), array([4])],
#  '1002_p': [array([0., 0., 0., ..., 0., 0., 0.]), array([4])],
#  '1003_c': [array([0., 0., 0., ..., 0., 0., 0.]), array([11])],
#  '1003_p': [array([0., 0., 0., ..., 0., 0., 0.]), array([4])],
#  '1004_c': [array([0., 0., 0., ..., 0., 0., 0.]), array([8])],
#  '1005_c': [array([0., 0., 0., ..., 0., 0., 0.]), array([14])],
#  '1005_p': [array([0., 0., 0., ..., 0., 0., 0.]), array([4])],
#  '1006_c': [array([0., 0., 0., ..., 0., 0., 0.]), array([10])],
#  '1006_p': [array([0., 0., 0., ..., 0., 0., 0.]), array([4])],
#  '1007_c': [array([0., 0., 0., ..., 0., 0., 0.]), array([7])],
#  '1007_p': [array([0., 0., 0., ..., 0., 0., 0.]), array([4])],
#  '1008_c': [array([0., 0., 0., ..., 0., 0., 0.]), array([7])],
#  '1008_p': [array([0., 0., 0., ..., 0., 0., 0.]), array([4])],
#  '1009_c': [array([0., 0., 0., ..., 0., 0., 0.]), array([7])],
#  '1009_p': [array([0., 0., 0., ..., 0., 0., 0.]), array([4])],
#  '100_c': [array([0., 0., 0., ..., 0., 0., 0.]), array([7])],
#  '1010_c': [array([0., 0., 0., ..., 0., 0., 0.]), array([7])],
#  '1010_p': [array([0., 0., 0., ..., 0., 0., 0.]), array([4])],
#  '1011_c': [array([0., 0., 0., ..., 0., 0., 0.]), array([7])],
#  '1012_c': [array([0., 0., 0., ..., 0., 0., 0.]), array([7])],
#  '1012_p': [array([0., 0., 0., ..., 0., 0., 0.]), array([4])],
#  '1013_c': [array([0., 0., 0., ..., 0., 0., 0.]), array([7])],
#  '1013_p': [array([0., 0., 0., ..., 0., 0., 0.]), array([4])],
#  '1014_c': [array([0., 0., 0., ..., 0., 0., 0.]), array([7])],
#  '1015_c': [array([0., 0., 0., ..., 0., 0., 0.]), array([7])],
#  '1015_p': [array([0., 0., 0., ..., 0., 0., 0.]), array([4])],
#  '1016_c': [array([0., 0., 0., ..., 0., 0., 0.]), array([11])],
#  '1016_p': [array([0., 0., 0., ..., 0., 0., 0.]), array([4])],
#  '1017_c': [array([0., 0., 0., ..., 0., 0., 0.]), array([10])],
#  '1017_p': [array([0., 0., 0., ..., 0., 0., 0.]), array([4])],
#  '1018_c': [array([0., 0., 0., ..., 0., 0., 0.]), array([7])],
#  '1018_p': [array([0., 0., 0., ..., 0., 0., 0.]), array([4])],
#  '1019_c': [array([0., 0., 0., ..., 0., 0., 0.]), array([7])],
#  '1019_p': [array([0., 0., 0., ..., 0., 0., 0.]), array([4])],
#  '101_c': [array([0., 0., 0., ..., 0., 0., 0.]), array([8])],
#  '101_p': [array([0., 0., 0., ..., 0., 0., 0.]), array([1])],
#  '1020_c': [array([0., 0., 0., ..., 0., 0., 0.]), array([8])],
#  '1021_c': [array([0., 0., 0., ..., 0., 0., 0.]), array([8])],
#  '1022_c': [array([0., 0., 0., ..., 0., 0., 0.]), array([8])],
#  '1022_p': [array([0., 0., 0., ..., 0., 0., 0.]), array([4])],
#  '1023_c': [array([0., 0., 0., ..., 0., 0., 0.]), array([7])],
#  '1024_c': [array([0., 0., 0., ..., 0., 0., 0.]), array([8])],
#  '1024_p': [array([0., 0., 0., ..., 0., 0., 0.]), array([4])],
#  '1025_p': [array([0., 0., 0., ..., 0., 0., 0.]), array([4])],
#  '1026_c': [array([0., 0., 0., ..., 0., 0., 0.]), array([7])],
#  '1026_p': [array([0., 0., 0., ..., 0., 0., 0.]), array([4])],
#  '1027_c': [array([0., 0., 0., ..., 0., 0., 0.]), array([8])],
#  '1027_p': [array([0., 0., 0., ..., 0., 0., 0.]), array([4])],
#  '1028_c': [array([0., 0., 0., ..., 0., 0., 0.]), array([7])],
#  '1029_c': [array([0., 0., 0., ..., 0., 0., 0.]), array([8])],
#  '102_c': [array([0., 0., 0., ..., 0., 0., 0.]), array([8])],
#  '102_p': [array([0., 0., 0., ..., 0., 0., 0.]), array([1])],
#  '1031_c': [array([0., 0., 0., ..., 0., 0., 0.]), array([15])],
#  '1031_p': [array([0., 0., 0., ..., 0., 0., 0.]), array([4])],
#  '1033_p': [array([0., 0., 0., ..., 0., 0., 0.]), array([4])],
#  '1034_c': [array([0., 0., 0., ..., 0., 0., 0.]), array([8])],
#  '1034_p': [array([0., 0., 0., ..., 0., 0., 0.]), array([4])],
#  '1036_p': [array([0., 0., 0., ..., 0., 0., 0.]), array([4])],
#  '1037_c': [array([0., 0., 0., ..., 0., 0., 0.]), array([8])],
#  '1038_c': [array([0., 0., 0., ..., 0., 0., 0.]), array([7])],
#  '1038_p': [array([0., 0., 0., ..., 0., 0., 0.]), array([4])],
#  '1039_c': [array([0., 0., 0., ..., 0., 0., 0.]), array([7])],
#  '1039_p': [array([0., 0., 0., ..., 0., 0., 0.]), array([4])],
#  '103_c': [array([0., 0., 0., ..., 0., 0., 0.]), array([8])],
#  '103_p': [array([0., 0., 0., ..., 0., 0., 0.]), array([1])],
#  '1040_c': [array([0., 0., 0., ..., 0., 0., 0.]), array([8])],
#  '1041_c': [array([0., 0., 0., ..., 0., 0., 0.]), array([17])],
#  '1042_c': [array([0., 0., 0., ..., 0., 0., 0.]), array([17])],
#  '1042_p': [array([0., 0., 0., ..., 0., 0., 0.]), array([4])],
#  '1043_c': [array([0., 0., 0., ..., 0., 0., 0.]), array([8])],
#  '1043_p': [array([0., 0., 0., ..., 0., 0., 0.]), array([4])],
#  '1044_c': [array([0., 0., 0., ..., 0., 0., 0.]), array([7])],
#  '1045_p': [array([0., 0., 0., ..., 0., 0., 0.]), array([4])],
#  '1046_c': [array([0., 0., 0., ..., 0., 0., 0.]), array([16])],
#  '1047_c': [array([0., 0., 0., ..., 0., 0., 0.]), array([10])],
#  '1047_p': [array([0., 0., 0., ..., 0., 0., 0.]), array([4])],
#  '1048_c': [array([0., 0., 0., ..., 0., 0., 0.]), array([7])],
#  '1048_p': [array([0., 0., 0., ..., 0., 0., 0.]), array([4])],
#  '1049_p': [array([0., 0., 0., ..., 0., 0., 0.]), array([4])],
#  '104_c': [array([0., 0., 0., ..., 0., 0., 0.]), array([7])],
#  '104_p': [array([0., 0., 0., ..., 0., 0., 0.]), array([1])],
#  '1050_c': [array([0., 0., 0., ..., 0., 0., 0.]), array([11])],
#  '1050_p': [array([0., 0., 0., ..., 0., 0., 0.]), array([4])],
#  '1051_c': [array([0., 0., 0., ..., 0., 0., 0.]), array([7])],
#  '1051_p': [array([0., 0., 0., ..., 0., 0., 0.]), array([4])],
#  '1052_c': [array([0., 0., 0., ..., 0., 0., 0.]), array([11])],
#  '1052_p': [array([0., 0., 0., ..., 0., 0., 0.]), array([4])],
#  '1054_c': [array([0., 0., 0., ..., 0., 0., 0.]), array([7])],
#  '1055_c': [array([0., 0., 0., ..., 0., 0., 0.]), array([10])],
#  '1055_p': [array([0., 0., 0., ..., 0., 0., 0.]), array([4])],
#  '1056_c': [array([0., 0., 0., ..., 0., 0., 0.]), array([10])],
#  '1057_c': [array([0., 0., 0., ..., 0., 0., 0.]), array([8])],
#  '1057_p': [array([0., 0., 0., ..., 0., 0., 0.]), array([4])],
#  '1058_c': [array([0., 0., 0., ..., 0., 0., 0.]), array([7])],
#  '1058_p': [array([0., 0., 0., ..., 0., 0., 0.]), array([4])],
#  '1059_c': [array([0., 0., 0., ..., 0., 0., 0.]), array([7])],
#  '1059_p': [array([0., 0., 0., ..., 0., 0., 0.]), array([4])],
#  '105_c': [array([0., 0., 0., ..., 0., 0., 0.]), array([7])],
#  '105_p': [array([0., 0., 0., ..., 0., 0., 0.]), array([1])],
#  '1060_p': [array([0., 0., 0., ..., 0., 0., 0.]), array([4])],
#  '1061_c': [array([0., 0., 0., ..., 0., 0., 0.]), array([7])],
#  '1061_p': [array([0., 0., 0., ..., 0., 0., 0.]), array([4])],
#  '1062_c': [array([0., 0., 0., ..., 0., 0., 0.]), array([7])],
#  '1062_p': [array([0., 0., 0., ..., 0., 0., 0.]), array([4])],
#  '1063_c': [array([0., 0., 0., ..., 0., 0., 0.]), array([7])],
#  '1063_p': [array([0., 0., 0., ..., 0., 0., 0.]), array([4])],
#  '1064_c': [array([0., 0., 0., ..., 0., 0., 0.]), array([7])],
#  '1064_p': [array([0., 0., 0., ..., 0., 0., 0.]), array([4])],
#  '1065_p': [array([0., 0., 0., ..., 0., 0., 0.]), array([4])],
#  '1066_c': [array([0., 0., 0., ..., 0., 0., 0.]), array([8])],
#  '1066_p': [array([0., 0., 0., ..., 0., 0., 0.]), array([4])],
#  '1067_c': [array([0., 0., 0., ..., 0., 0., 0.]), array([8])],
#  '1067_p': [array([0., 0., 0., ..., 0., 0., 0.]), array([4])],
#  '1068_c': [array([0., 0., 0., ..., 0., 0., 0.]), array([7])],
#  '1068_p': [array([0., 0., 0., ..., 0., 0., 0.]), array([4])],
#  '1069_c': [array([0., 0., 0., ..., 0., 0., 0.]), array([7])],
#  '106_c': [array([0., 0., 0., ..., 0., 0., 0.]), array([7])],
#  '1070_c': [array([0., 0., 0., ..., 0., 0., 0.]), array([8])],
#  '1070_p': [array([0., 0., 0., ..., 0., 0., 0.]), array([4])],
#  '1071_c': [array([0., 0., 0., ..., 0., 0., 0.]), array([8])],
#  '1072_c': [array([0., 0., 0., ..., 0., 0., 0.]), array([15])],
#  '1072_p': [array([0., 0., 0., ..., 0., 0., 0.]), array([4])],
#  '1073_c': [array([0., 0., 0., ..., 0., 0., 0.]), array([8])],
#  '1073_p': [array([0., 0., 0., ..., 0., 0., 0.]), array([4])],
#  '1074_c': [array([0., 0., 0., ..., 0., 0., 0.]), array([8])],
#  '1074_p': [array([0., 0., 0., ..., 0., 0., 0.]), array([4])],
#  '1075_p': [array([0., 0., 0., ..., 0., 0., 0.]), array([4])],
#  '1076_c': [array([0., 0., 0., ..., 0., 0., 0.]), array([8])],
#  '1076_p': [array([0., 0., 0., ..., 0., 0., 0.]), array([4])],
#  '1077_c': [array([0., 0., 0., ..., 0., 0., 0.]), array([7])],
#  '1077_p': [array([0., 0., 0., ..., 0., 0., 0.]), array([4])],
#  '1078_p': [array([0., 0., 0., ..., 0., 0., 0.]), array([0])],
#  '1079_p': [array([0., 0., 0., ..., 0., 0., 0.]), array([0])],
#  '107_c': [array([0., 0., 0., ..., 0., 0., 0.]), array([8])],
#  '1080_c': [array([0., 0., 0., ..., 0., 0., 0.]), array([8])],
#  '1080_p': [array([0., 0., 0., ..., 0., 0., 0.]), array([0])],
#  '1081_p': [array([0., 0., 0., ..., 0., 0., 0.]), array([0])],
#  '1082_c': [array([0., 0., 0., ..., 0., 0., 0.]), array([7])],
#  '1082_p': [array([0., 0., 0., ..., 0., 0., 0.]), array([0])],
#  '1083_p': [array([0., 0., 0., ..., 0., 0., 0.]), array([0])],
#  '1084_c': [array([0., 0., 0., ..., 0., 0., 0.]), array([10])],
#  '1084_p': [array([0., 0., 0., ..., 0., 0., 0.]), array([0])],
#  '1085_c': [array([0., 0., 0., ..., 0., 0., 0.]), array([7])],
#  '1085_p': [array([0., 0., 0., ..., 0., 0., 0.]), array([0])],
#  '1086_c': [array([0., 0., 0., ..., 0., 0., 0.]), array([10])],
#  '1086_p': [array([0., 0., 0., ..., 0., 0., 0.]), array([0])],
#  '1087_c': [array([0., 0., 0., ..., 0., 0., 0.]), array([7])],
#  '1088_c': [array([0., 0., 0., ..., 0., 0., 0.]), array([7])],
#  '1088_p': [array([0., 0., 0., ..., 0., 0., 0.]), array([0])],
#  '1089_p': [array([0., 0., 0., ..., 0., 0., 0.]), array([0])],
#  '108_c': [array([0., 0., 0., ..., 0., 0., 0.]), array([7])],
#  '108_p': [array([0., 0., 0., ..., 0., 0., 0.]), array([1])],
#  '1090_c': [array([0., 0., 0., ..., 0., 0., 0.]), array([7])],
#  '1091_c': [array([0., 0., 0., ..., 0., 0., 0.]), array([7])],
#  '1091_p': [array([0., 0., 0., ..., 0., 0., 0.]), array([0])],
#  '1092_c': [array([0., 0., 0., ..., 0., 0., 0.]), array([7])],
#  '1092_p': [array([0., 0., 0., ..., 0., 0., 0.]), array([0])],
#  '1093_c': [array([0., 0., 0., ..., 0., 0., 0.]), array([8])],
#  '1093_p': [array([0., 0., 0., ..., 0., 0., 0.]), array([0])],
#  '1094_c': [array([0., 0., 0., ..., 0., 0., 0.]), array([8])],
#  '1094_p': [array([0., 0., 0., ..., 0., 0., 0.]), array([0])],
#  '1095_c': [array([0., 0., 0., ..., 0., 0., 0.]), array([7])],
#  '1095_p': [array([0., 0., 0., ..., 0., 0., 0.]), array([0])],
#  '1096_c': [array([0., 0., 0., ..., 0., 0., 0.]), array([10])],
#  '1096_p': [array([0., 0., 0., ..., 0., 0., 0.]), array([0])],
#  '1097_c': [array([0., 0., 0., ..., 0., 0., 0.]), array([7])],
#  '1098_p': [array([0., 0., 0., ..., 0., 0., 0.]), array([0])],
#  '1099_c': [array([0., 0., 0., ..., 0., 0., 0.]), array([7])],
#  '1099_p': [array([0., 0., 0., ..., 0., 0., 0.]), array([0])],
#  '109_c': [array([0., 0., 0., ..., 0., 0., 0.]), array([7])],
#  '109_p': [array([0., 0., 0., ..., 0., 0., 0.]), array([1])],
#  '10_c': [array([0., 0., 0., ..., 0., 0., 0.]), array([7])],
#  '1100_c': [array([0., 0., 0., ..., 0., 0., 0.]), array([7])],
#  '1101_c': [array([0., 0., 0., ..., 0., 0., 0.]), array([7])],
#  '1101_p': [array([0., 0., 0., ..., 0., 0., 0.]), array([0])],
#  '1102_c': [array([0., 0., 0., ..., 0., 0., 0.]), array([7])],
#  '1103_c': [array([0., 0., 0., ..., 0., 0., 0.]), array([7])],
#  '1103_p': [array([0., 0., 0., ..., 0., 0., 0.]), array([0])],
#  '1104_p': [array([0., 0., 0., ..., 0., 0., 0.]), array([0])],
#  '1105_p': [array([0., 0., 0., ..., 0., 0., 0.]), array([0])],
#  '1106_c': [array([0., 0., 0., ..., 0., 0., 0.]), array([7])],
#  '1107_p': [array([0., 0., 0., ..., 0., 0., 0.]), array([0])],
#  '1108_p': [array([0., 0., 0., ..., 0., 0., 0.]), array([0])],
#  '1109_c': [array([0., 0., 0., ..., 0., 0., 0.]), array([10])],
#  '1109_p': [array([0., 0., 0., ..., 0., 0., 0.]), array([0])],
#  '110_c': [array([0., 0., 0., ..., 0., 0., 0.]), array([7])],
#  '110_p': [array([0., 0., 0., ..., 0., 0., 0.]), array([1])],
#  '1110_c': [array([0., 0., 0., ..., 0., 0., 0.]), array([15])],
#  '1111_c': [array([0., 0., 0., ..., 0., 0., 0.]), array([23])],
#  '1111_p': [array([0., 0., 0., ..., 0., 0., 0.]), array([0])],
#  '1112_p': [array([0., 0., 0., ..., 0., 0., 0.]), array([0])],
#  '1113_c': [array([0., 0., 0., ..., 0., 0., 0.]), array([7])],
#  '1113_p': [array([0., 0., 0., ..., 0., 0., 0.]), array([0])],
#  '1114_c': [array([0., 0., 0., ..., 0., 0., 0.]), array([7])],
#  '1114_p': [array([0., 0., 0., ..., 0., 0., 0.]), array([0])],
#  '1115_c': [array([0., 0., 0., ..., 0., 0., 0.]), array([7])],
#  '1118_c': [array([0., 0., 0., ..., 0., 0., 0.]), array([7])],
#  '1118_p': [array([0., 0., 0., ..., 0., 0., 0.]), array([0])],
#  '1119_c': [array([0., 0., 0., ..., 0., 0., 0.]), array([7])],
#  '111_c': [array([0., 0., 0., ..., 0., 0., 0.]), array([15])],
#  '111_p': [array([0., 0., 0., ..., 0., 0., 0.]), array([1])],
#  '1120_c': [array([0., 0., 0., ..., 0., 0., 0.]), array([8])],
#  '1120_p': [array([0., 0., 0., ..., 0., 0., 0.]), array([0])],
#  '1121_c': [array([0., 0., 0., ..., 0., 0., 0.]), array([16])],
#  '1121_p': [array([0., 0., 0., ..., 0., 0., 0.]), array([0])],
#  '1123_c': [array([0., 0., 0., ..., 0., 0., 0.]), array([7])],
#  '1124_c': [array([0., 0., 0., ..., 0., 0., 0.]), array([10])],
#  '1124_p': [array([0., 0., 0., ..., 0., 0., 0.]), array([0])],
#  '1125_c': [array([0., 0., 0., ..., 0., 0., 0.]), array([7])],
#  '1125_p': [array([0., 0., 0., ..., 0., 0., 0.]), array([0])],
#  '1126_p': [array([0., 0., 0., ..., 0., 0., 0.]), array([0])],
#  '1127_c': [array([0., 0., 0., ..., 0., 0., 0.]), array([8])],
#  '1128_c': [array([0., 0., 0., ..., 0., 0., 0.]), array([7])],
#  '1128_p': [array([0., 0., 0., ..., 0., 0., 0.]), array([0])],
#  '1129_c': [array([0., 0., 0., ..., 0., 0., 0.]), array([7])],
#  '1129_p': [array([0., 0., 0., ..., 0., 0., 0.]), array([0])],
#  '112_p': [array([0., 0., 0., ..., 0., 0., 0.]), array([1])],
#  '1130_c': [array([0., 0., 0., ..., 0., 0., 0.]), array([7])],
#  '1130_p': [array([0., 0., 0., ..., 0., 0., 0.]), array([0])],
#  '1131_c': [array([0., 0., 0., ..., 0., 0., 0.]), array([8])],
#  '1132_c': [array([0., 0., 0., ..., 0., 0., 0.]), array([8])],
#  '1133_c': [array([0., 0., 0., ..., 0., 0., 0.]), array([8])],
#  '1134_c': [array([0., 0., 0., ..., 0., 0., 0.]), array([8])],
#  '1135_p': [array([0., 0., 0., ..., 0., 0., 0.]), array([0])],
#  '1136_c': [array([0., 0., 0., ..., 0., 0., 0.]), array([7])],
#  '1136_p': [array([0., 0., 0., ..., 0., 0., 0.]), array([0])],
#  '1137_c': [array([0., 0., 0., ..., 0., 0., 0.]), array([7])],
#  '1137_p': [array([0., 0., 0., ..., 0., 0., 0.]), array([0])],
#  '1138_p': [array([0., 0., 0., ..., 0., 0., 0.]), array([0])],
#  '1139_c': [array([0., 0., 0., ..., 0., 0., 0.]), array([10])],
#  '1139_p': [array([0., 0., 0., ..., 0., 0., 0.]), array([0])],
#  '113_c': [array([0., 0., 0., ..., 0., 0., 0.]), array([7])],
#  '1140_c': [array([0., 0., 0., ..., 0., 0., 0.]), array([7])],
#  '1140_p': [array([0., 0., 0., ..., 0., 0., 0.]), array([0])],
#  '1141_p': [array([0., 0., 0., ..., 0., 0., 0.]), array([0])],
#  '1142_c': [array([0., 0., 0., ..., 0., 0., 0.]), array([7])],
#  '1142_p': [array([0., 0., 0., ..., 0., 0., 0.]), array([0])],
#  '1143_c': [array([0., 0., 0., ..., 0., 0., 0.]), array([7])],
#  '1143_p': [array([0., 0., 0., ..., 0., 0., 0.]), array([0])],
#  '1144_c': [array([0., 0., 0., ..., 0., 0., 0.]), array([7])],
#  '1144_p': [array([0., 0., 0., ..., 0., 0., 0.]), array([0])],
#  '1145_c': [array([0., 0., 0., ..., 0., 0., 0.]), array([14])],
#  '1145_p': [array([0., 0., 0., ..., 0., 0., 0.]), array([0])],
#  '1146_c': [array([0., 0., 0., ..., 0., 0., 0.]), array([8])],
#  '1146_p': [array([0., 0., 0., ..., 0., 0., 0.]), array([0])],
#  '1147_c': [array([0., 0., 0., ..., 0., 0., 0.]), array([8])],
#  '1147_p': [array([0., 0., 0., ..., 0., 0., 0.]), array([0])],
#  '1148_c': [array([0., 0., 0., ..., 0., 0., 0.]), array([11])],
#  '1149_c': [array([0., 0., 0., ..., 0., 0., 0.]), array([7])],
#  '
c': [array([0., 0., 0., ..., 0., 0., 0.]), array([8])],
#  '1448_p': [array([0., 0., 0., ..., 0., 0., 0.]), array([0])],
#  '1449_c': [array([0., 0., 0., ..., 0., 0., 0.]), array([7])],
#  '1449_p': [array([0., 0., 0., ..., 0., 0., 0.]), array([0])],
#  '144_c': [array([0., 0., 0., ..., 0., 0., 0.]), array([7])],
#  '144_p': [array([0., 0., 0., ..., 0., 0., 0.]), array([0])],
#  '1450_c': [array([0., 0., 0., ..., 0., 0., 0.]), array([7])],
#  '1450_p': [array([0., 0., 0., ..., 0., 0., 0.]), array([0])],
#  '1451_c': [array([0., 0., 0., ..., 0., 0., 0.]), array([7])],
#  '1451_p': [array([0., 0., 0., ..., 0., 0., 0.]), array([0])],
#  '1452_p': [array([0., 0., 0., ..., 0., 0., 0.]), array([0])],
#  '1453_c': [array([0., 0., 0., ..., 0., 0., 0.]), array([11])],
#  '1453_p': [array([0., 0., 0., ..., 0., 0., 0.]), array([0])],
#  '1454_c': [array([0., 0., 0., ..., 0., 0., 0.]), array([21])],
#  '1455_p': [array([0., 0., 0., ..., 0., 0., 0.]), array([0])],
#  '1456_c': [array([0., 0., 0., ..., 0., 0., 0.]), array([10])],
#  '1457_c': [array([0., 0., 0., ..., 0., 0., 0.]), array([14])],
#  '1457_p': [array([0., 0., 0., ..., 0., 0., 0.]), array([0])],
#  '1458_c': [array([0., 0., 0., ..., 0., 0., 0.]), array([8])],
#  '1459_c': [array([0., 0., 0., ..., 0., 0., 0.]), array([7])],
#  '1459_p': [array([0., 0., 0., ..., 0., 0., 0.]), array([0])],
#  '145_p': [array([0., 0., 0., ..., 0., 0., 0.]), array([0])],
#  '1460_c': [array([0., 0., 0., ..., 0., 0., 0.]), array([7])],
#  '1460_p': [array([0., 0., 0., ..., 0., 0., 0.]), array([0])],
#  '1461_c': [array([0., 0., 0., ..., 0., 0., 0.]), array([11])],
#  '1461_p': [array([0., 0., 0., ..., 0., 0., 0.]), array([0])],
#  '1462_c': [array([0., 0., 0., ..., 0., 0., 0.]), array([10])],
#  '1462_p': [array([0., 0., 0., ..., 0., 0., 0.]), array([0])],
#  '1463_p': [array([0., 0., 0., ..., 0., 0., 0.]), array([0])],
#  '1464_c': [array([0., 0., 0., ..., 0., 0., 0.]), array([8])],
#  '1464_p': [array([0., 0., 0., ..., 0., 0., 0.]), array([0])],
#  '1465_c': [array([0., 0., 0., ..., 0., 0., 0.]), array([8])],
#  '1465_p': [array([0., 0., 0., ..., 0., 0., 0.]), array([0])],
#  '1466_p': [array([0., 0., 0., ..., 0., 0., 0.]), array([0])],
#  '1467_p': [array([0., 0., 0., ..., 0., 0., 0.]), array([0])],
#  '1468_c': [array([0., 0., 0., ..., 0., 0., 0.]), array([7])],
#  '1468_p': [array([0., 0., 0., ..., 0., 0., 0.]), array([0])],
#  '1469_p': [array([0., 0., 0., ..., 0., 0., 0.]), array([0])],
#  '146_c': [array([0., 0., 0., ..., 0., 0., 0.]), array([7])],
#  '146_p': [array([0., 0., 0., ..., 0., 0., 0.]), array([0])],
#  '1470_c': [array([0., 0., 0., ..., 0., 0., 0.]), array([7])],
#  '1470_p': [array([0., 0., 0., ..., 0., 0., 0.]), array([0])],
#  '1471_c': [array([0., 0., 0., ..., 0., 0., 0.]), array([7])],
#  '1471_p': [array([0., 0., 0., ..., 0., 0., 0.]), array([0])],
#  '1472_c': [array([0., 0., 0., ..., 0., 0., 0.]), array([7])],
#  '1472_p': [array([0., 0., 0., ..., 0., 0., 0.]), array([0])],
#  '1473_c': [array([0., 0., 0., ..., 0., 0., 0.]), array([7])],
#  '1473_p': [array([0., 0., 0., ..., 0., 0., 0.]), array([0])],
#  '1474_c': [array([0., 0., 0., ..., 0., 0., 0.]), array([19])],
#  '1474_p': [array([0., 0., 0., ..., 0., 0., 0.]), array([0])],
#  '1475_c': [array([0., 0., 0., ..., 0., 0., 0.]), array([10])],
#  '1475_p': [array([0., 0., 0., ..., 0., 0., 0.]), array([0])],
#  '1476_c': [array([0., 0., 0., ..., 0., 0., 0.]), array([8])],
#  '1476_p': [array([0., 0., 0., ..., 0., 0., 0.]), array([0])],
#  '1477_c': [array([0., 0., 0., ..., 0., 0., 0.]), array([8])],
#  '1477_p': [array([0., 0., 0., ..., 0., 0., 0.]), array([0])],
#  '1478_c': [array([0., 0., 0., ..., 0., 0., 0.]), array([7])],
#  '1478_p': [array([0., 0., 0., ..., 0., 0., 0.]), array([0])],
#  '1479_c': [array([0., 0., 0., ..., 0., 0., 0.]), array([7])],
#  '1479_p': [array([0., 0., 0., ..., 0., 0., 0.]), array([0])],
#  '147_c': [array([0., 0., 0., ..., 0., 0., 0.]), array([7])],
#  '147_p': [array([0., 0., 0., ..., 0., 0., 0.]), array([0])],
#  '1480_c': [array([0., 0., 0., ..., 0., 0., 0.]), array([7])],
#  '1480_p': [array([0., 0., 0., ..., 0., 0., 0.]), array([0])],
#  '1481_c': [array([0., 0., 0., ..., 0., 0., 0.]), array([8])],
#  '1481_p': [array([0., 0., 0., ..., 0., 0., 0.]), array([0])],
#  '1482_c': [array([0., 0., 0., ..., 0., 0., 0.]), array([7])],
#  '1482_p': [array([0., 0., 0., ..., 0., 0., 0.]), array([0])],
#  '1483_c': [array([0., 0., 0., ..., 0., 0., 0.]), array([15])],
#  '1483_p': [array([0., 0., 0., ..., 0., 0., 0.]), array([0])],
#  '1484_c': [array([0., 0., 0., ..., 0., 0., 0.]), array([7])],
#  '1484_p': [array([0., 0., 0., ..., 0., 0., 0.]), array([0])],
#  '1485_c': [array([0., 0., 0., ..., 0., 0., 0.]), array([7])],
#  '1486_c': [array([0., 0., 0., ..., 0., 0., 0.]), array([8])],
#  '1486_p': [array([0., 0., 0., ..., 0., 0., 0.]), array([0])],
#  '1487_c': [array([0., 0., 0., ..., 0., 0., 0.]), array([8])],
#  '1488_c': [array([0., 0., 0., ..., 0., 0., 0.]), array([10])],
#  '1488_p': [array([0., 0., 0., ..., 0., 0., 0.]), array([0])],
#  '1489_c': [array([0., 0., 0., ..., 0., 0., 0.]), array([8])],
#  '1489_p': [array([0., 0., 0., ..., 0., 0., 0.]), array([0])],
#  '148_c': [array([0., 0., 0., ..., 0., 0., 0.]), array([7])],
#  '148_p': [array([0., 0., 0., ..., 0., 0., 0.]), array([0])],
#  '1490_c': [array([0., 0., 0., ..., 0., 0., 0.]), array([8])],
#  '1490_p': [array([0., 0., 0., ..., 0., 0., 0.]), array([0])],
#  '1491_c': [array([0., 0., 0., ..., 0., 0., 0.]), array([8])],
#  '1492_c': [array([0., 0., 0., ..., 0., 0., 0.]), array([7])],
#  '1492_p': [array([0., 0., 0., ..., 0., 0., 0.]), array([0])],
#  '1493_c': [array([0., 0., 0., ..., 0., 0., 0.]), array([7])],
#  '1493_p': [array([0., 0., 0., ..., 0., 0., 0.]), array([0])],
#  '1494_c': [array([0., 0., 0., ..., 0., 0., 0.]), array([10])],
#  '1494_p': [array([0., 0., 0., ..., 0., 0., 0.]), array([0])],
#  '1495_p': [array([0., 0., 0., ..., 0., 0., 0.]), array([0])],
#  '1496_p': [array([0., 0., 0., ..., 0., 0., 0.]), array([0])],
#  '1497_c': [array([0., 0., 0., ..., 0., 0., 0.]), array([8])],
#  '1497_p': [array([0., 0., 0., ..., 0., 0., 0.]), array([0])],
#  '1498_c': [array([0., 0., 0., ..., 0., 0., 0.]), array([8])],
#  '1499_c': [array([0., 0., 0., ..., 0., 0., 0.]), array([8])],
#  '1499_p': [array([0., 0., 0., ..., 0., 0., 0.]), array([0])],
#  '149_c': [array([0., 0., 0., ..., 0., 0., 0.]), array([7])],
#  '149_p': [array([0., 0., 0., ..., 0., 0., 0.]), array([0])],
#  '14_c': [array([0., 0., 0., ..., 0., 0., 0.]), array([11])],
#  '14_p': [array([0., 0., 0., ..., 0., 0., 0.]), array([0])],
#  '1500_c': [array([0., 0., 0., ..., 0., 0., 0.]), array([7])],
#  '1500_p': [array([0., 0., 0., ..., 0., 0., 0.]), array([0])],
#  '1501_c': [array([0., 0., 0., ..., 0., 0., 0.]), array([7])],
#  '1501_p': [array([0., 0., 0., ..., 0., 0., 0.]), array([0])],
#  '1502_c': [array([0., 0., 0., ..., 0., 0., 0.]), array([7])],
#  '1502_p': [array([0., 0., 0., ..., 0., 0., 0.]), array([0])],
#  '1503_p': [array([0., 0., 0., ..., 0., 0., 0.]), array([1])],
#  '1504_c': [array([0., 0., 0., ..., 0., 0., 0.]), array([12])],
#  '1505_c': [array([0., 0., 0., ..., 0., 0., 0.]), array([8])],
#  '1505_p': [array([0., 0., 0., ..., 0., 0., 0.]), array([1])],
#  '1506_c': [array([0., 0., 0., ..., 0., 0., 0.]), array([7])],
#  '1506_p': [array([0., 0., 0., ..., 0., 0., 0.]), array([1])],
#  '1507_c': [array([0., 0., 0., ..., 0., 0., 0.]), array([8])],
#  '1507_p': [array([0., 0., 0., ..., 0., 0., 0.]), array([1])],
#  '1508_p': [array([0., 0., 0., ..., 0., 0., 0.]), array([1])],
#  '1509_c': [array([0., 0., 0., ..., 0., 0., 0.]), array([11])],
#  '1509_p': [array([0., 0., 0., ..., 0., 0., 0.]), array([1])],
#  '150_c': [array([0., 0., 0., ..., 0., 0., 0.]), array([7])],
#  '150_p': [array([0., 0., 0., ..., 0., 0., 0.]), array([0])],
#  '1510_p': [array([0., 0., 0., ..., 0., 0., 0.]), array([4])],
#  '1511_c': [array([0., 0., 0., ..., 0., 0., 0.]), array([7])],
#  '1511_p': [array([0., 0., 0., ..., 0., 0., 0.]), array([4])],
#  '1512_c': [array([0., 0., 0., ..., 0., 0., 0.]), array([7])],
#  '1512_p': [array([0., 0., 0., ..., 0., 0., 0.]), array([4])],
#  '1513_c': [array([0., 0., 0., ..., 0., 0., 0.]), array([7])],
#  '1513_p': [array([0., 0., 0., ..., 0., 0., 0.]), array([4])],
#  '1514_c': [array([0., 0., 0., ..., 0., 0., 0.]), array([7])],
#  '1514_p': [array([0., 0., 0., ..., 0., 0., 0.]), array([4])],
#  '1515_c': [array([0., 0., 0., ..., 0., 0., 0.]), array([7])],
#  '1515_p': [array([0., 0., 0., ..., 0., 0., 0.]), array([4])],
#  '1516_c': [array([0., 0., 0., ..., 0., 0., 0.]), array([27])],
#  '1516_p': [array([0., 0., 0., ..., 0., 0., 0.]), array([4])],
#  '1517_p': [array([0., 0., 0., ..., 0., 0., 0.]), array([3])],
#  '1518_p': [array([0., 0., 0., ..., 0., 0., 0.]), array([3])],
#  '1519_c': [array([0., 0., 0., ..., 0., 0., 0.]), array([8])],
#  '1519_p': [array([0., 0., 0., ..., 0., 0., 0.]), array([3])],
#  '151_c': [array([0., 0., 0., ..., 0., 0., 0.]), array([8])],
#  '151_p': [array([0., 0., 0., ..., 0., 0., 0.]), array([0])],
#  '1521_c': [array([0., 0., 0., ..., 0., 0., 0.]), array([7])],
#  '1521_p': [array([0., 0., 0., ..., 0., 0., 0.]), array([3])],
#  '1522_c': [array([0., 0., 0., ..., 0., 0., 0.]), array([7])],
#  '1522_p': [array([0., 0., 0., ..., 0., 0., 0.]), array([3])],
#  '1523_c': [array([0., 0., 0., ..., 0., 0., 0.]), array([11])],
#  '1524_c': [array([0., 0., 0., ..., 0., 0., 0.]), array([7])],
#  '1524_p': [array([0., 0., 0., ..., 0., 0., 0.]), array([3])],
#  '1526_p': [array([0., 0., 0., ..., 0., 0., 0.]), array([3])],
#  '1527_c': [array([0., 0., 0., ..., 0., 0., 0.]), array([7])],
#  '1527_p': [array([0., 0., 0., ..., 0., 0., 0.]), array([3])],
#  '1528_c': [array([0., 0., 0., ..., 0., 0., 0.]), array([7])],
#  '1528_p': [array([0., 0., 0., ..., 0., 0., 0.]), array([3])],
#  '1529_c': [array([0., 0., 0., ..., 0., 0., 0.]), array([13])],
#  '152_c': [array([0., 0., 0., ..., 0., 0., 0.]), array([8])],
#  '152_p': [array([0., 0., 0., ..., 0., 0., 0.]), array([0])],
#  '1531_c': [array([0., 0., 0., ..., 0., 0., 0.]), array([7])],
#  '1531_p': [array([0., 0., 0., ..., 0., 0., 0.]), array([3])],
#  '1532_c': [array([0., 0., 0., ..., 0., 0., 0.]), array([12])],
#  '1532_p': [array([0., 0., 0., ..., 0., 0., 0.]), array([3])],
#  '1533_p': [array([0., 0., 0., ..., 0., 0., 0.]), array([3])],
#  '1534_c': [array([0., 0., 0., ..., 0., 0., 0.]), array([8])],
#  '1534_p': [array([0., 0., 0., ..., 0., 0., 0.]), array([3])],
#  '1535_c': [array([0., 0., 0., ..., 0., 0., 0.]), array([7])],
#  '1535_p': [array([0., 0., 0., ..., 0., 0., 0.]), array([3])],
#  '1536_c': [array([0., 0., 0., ..., 0., 0., 0.]), array([7])],
#  '1536_p': [array([0., 0., 0., ..., 0., 0., 0.]), array([3])],
#  '1537_c': [array([0., 0., 0., ..., 0., 0., 0.]), array([10])],
#  '1537_p': [array([0., 0., 0., ..., 0., 0., 0.]), array([3])],
#  '1538_c': [array([0., 0., 0., ..., 0., 0., 0.]), array([8])],
#  '1538_p': [array([0., 0., 0., ..., 0., 0., 0.]), array([3])],
#  '1539_c': [array([0., 0., 0., ..., 0., 0., 0.]), array([7])],
#  '153_c': [array([0., 0., 0., ..., 0., 0., 0.]), array([7])],
#  '1540_c': [array([0., 0., 0., ..., 0., 0., 0.]), array([7])],
#  '1540_p': [array([0., 0., 0., ..., 0., 0., 0.]), array([3])],
#  '1541_p': [array([0., 0., 0., ..., 0., 0., 0.]), array([3])],
#  '1543_c': [array([0., 0., 0., ..., 0., 0., 0.]), array([7])],
#  '1543_p': [array([0., 0., 0., ..., 0., 0., 0.]), array([3])],
#  '1544_p': [array([0., 0., 0., ..., 0., 0., 0.]), array([3])],
#  '1545_p': [array([0., 0., 0., ..., 0., 0., 0.]), array([3])],
#  '1546_c': [array([0., 0., 0., ..., 0., 0., 0.]), array([11])],
#  '1546_p': [array([0., 0., 0., ..., 0., 0., 0.]), array([3])],
#  '1547_c': [array([0., 0., 0., ..., 0., 0., 0.]), array([7])],
#  '1547_p': [array([0., 0., 0., ..., 0., 0., 0.]), array([3])],
#  '1548_c': [array([0., 0., 0., ..., 0., 0., 0.]), array([7])],
#  '1548_p': [array([0., 0., 0., ..., 0., 0., 0.]), array([3])],
#  '1549_c': [array([0., 0., 0., ..., 0., 0., 0.]), array([11])],
#  '1549_p': [array([0., 0., 0., ..., 0., 0., 0.]), array([3])],
#  '154_p': [array([0., 0., 0., ..., 0., 0., 0.]), array([0])],
#  '1550_c': [array([0., 0., 0., ..., 0., 0., 0.]), array([7])],
#  '1550_p': [array([0., 0., 0., ..., 0., 0., 0.]), array([3])],
#  '1551_c': [array([0., 0., 0., ..., 0., 0., 0.]), array([7])],
#  '1552_c': [array([0., 0., 0., ..., 0., 0., 0.]), array([8])],
#  '1552_p': [array([0., 0., 0., ..., 0., 0., 0.]), array([3])],
#  '1553_c': [array([0., 0., 0., ..., 0., 0., 0.]), array([7])],
#  '1553_p': [array([0., 0., 0., ..., 0., 0., 0.]), array([3])],
#  '1554_c': [array([0., 0., 0., ..., 0., 0., 0.]), array([7])],
#  '1554_p': [array([0., 0., 0., ..., 0., 0., 0.]), array([3])],
#  '1555_c': [array([0., 0., 0., ..., 0., 0., 0.]), array([10])],
#  '1557_c': [array([0., 0., 0., ..., 0., 0., 0.]), array([7])],
#  '1557_p': [array([0., 0., 0., ..., 0., 0., 0.]), array([3])],
#  '1558_c': [array([0., 0., 0., ..., 0., 0., 0.]), array([10])],
#  '1559_c': [array([0., 0., 0., ..., 0., 0., 0.]), array([8])],
#  '1559_p': [array([0., 0., 0., ..., 0., 0., 0.]), array([3])],
#  '155_c': [array([0., 0., 0., ..., 0., 0., 0.]), array([7])],
#  '155_p': [array([0., 0., 0., ..., 0., 0., 0.]), array([0])],
#  ...}
